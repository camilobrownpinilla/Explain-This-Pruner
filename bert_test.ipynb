# %% [markdown]
# Notebook to test displays.
#
# Supports any model & tokenizer from huggingface

# %%
from transformers import AutoTokenizer, BertForSequenceClassification
from explainers.explanation_methods import SHAP, LIME
import shap
import torch


tokenizer = AutoTokenizer.from_pretrained(
    "textattack/bert-base-uncased-yelp-polarity")
model = BertForSequenceClassification.from_pretrained(
    "textattack/bert-base-uncased-yelp-polarity")
print('model loaded')

input = 'Hello, my dog is so terribly ugly'
tokenized_input = tokenizer(input, return_tensors="pt")
label = torch.tensor([0]).unsqueeze(0)  # Batch size 1

with torch.no_grad():
    output = model(**tokenized_input, labels=label)
    
loss, logits = output[:2]
predicted_class_id = logits.argmax().item()
predicted_class = model.config.id2label[predicted_class_id] 
true_class = model.config.id2label[label[0].item()]   

print(f'input: {input}\n logits: {logits} \n predicted class: {predicted_class} \n true class: {true_class}')


explainer = SHAP(model, tokenizer)
explanation = explainer.explain(input)
print('SHAP explanation: ', explanation)

shap.plots.text(explanation)
# Out:
# model loaded
# input: Hello, my dog is so terribly ugly
#  logits: tensor([[ 4.5232, -4.2648]])
#  predicted class: LABEL_0
#  true class: LABEL_0
# SHAP explanation:  [[ 0.          0.        ]
#  [-0.10023548  0.10023542]
#  [ 0.011923   -0.01192299]
#  [-0.01269054  0.01269055]
#  [ 0.0038579  -0.0038579 ]
#  [ 0.02124363 -0.02124363]
#  [ 0.04590302 -0.04590301]
#  [ 0.02927343 -0.02927346]
#  [ 0.02953256 -0.02953256]
#  [ 0.          0.        ]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 32
#      29 explanation = explainer.explain(input)
#      30 print('SHAP explanation: ', explanation)
# ---> 32 shap.plots.text(explanation)
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/shap/plots/_text.py:81, in text(shap_values, num_starting_labels, grouping_threshold, separator, xmin, xmax, cmax, display)
#      78 uuid = ''.join(random.choices(string.ascii_lowercase, k=20))
#      80 # loop when we get multi-row inputs
# ---> 81 if len(shap_values.shape) == 2 and (shap_values.output_names is None or isinstance(shap_values.output_names, str)):
#      82     xmin = 0
#      83     xmax = 0
#
# AttributeError: 'numpy.ndarray' object has no attribute 'output_names'

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification


model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
model = DistilBertForSequenceClassification.from_pretrained(model_name)
print('model loaded')

input = "i went and saw this movie last night after being coaxed to by a few friends of mine . i ' ll admit that i was reluctant to see it because from what i knew of ashton kutcher he was only able to do comedy . i was wrong . kutcher played the character of jake fischer very well , and kevin costner played ben randall with such professionalism . the sign of a good movie is that it can toy with our emotions . this one did exactly that . the entire theater ( which was sold out ) was overcome by laughter during the"

explainer = LIME(model, tokenizer)
explanation = explainer.explain(input)
print('explanation obtained')
shap.plots.text(explanation)
# Out:
# model loaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#       9 input = "i went and saw this movie last night after being coaxed to by a few friends of mine . i ' ll admit that i was reluctant to see it because from what i knew of ashton kutcher he was only able to do comedy . i was wrong . kutcher played the character of jake fischer very well , and kevin costner played ben randall with such professionalism . the sign of a good movie is that it can toy with our emotions . this one did exactly that . the entire theater ( which was sold out ) was overcome by laughter during the"
#      11 explainer = LIME(model, tokenizer)
# ---> 12 explanation = explainer.explain(input)
#      13 print('explanation obtained')
#      14 shap.plots.text(explanation)
#
# File ~/Programming/harvardCS/PruningExplainability/explainers/explanation_methods.py:62, in LIME.explain(self, input)
#      61 def explain(self, input):
# ---> 62     exp = self.explainer.explain_instance(input, self.predict_proba)
#      64     return exp.as_list()
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/lime/lime_text.py:413, in LimeTextExplainer.explain_instance(self, text_instance, classifier_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     406 indexed_string = (IndexedCharacters(
#     407     text_instance, bow=self.bow, mask_string=self.mask_string)
#     408                   if self.char_level else
#     409                   IndexedString(text_instance, bow=self.bow,
#     410                                 split_expression=self.split_expression,
#     411                                 mask_string=self.mask_string))
#     412 domain_mapper = TextDomainMapper(indexed_string)
# --> 413 data, yss, distances = self.__data_labels_distances(
#     414     indexed_string, classifier_fn, num_samples,
#     415     distance_metric=distance_metric)
#     416 if self.class_names is None:
#     417     self.class_names = [str(x) for x in range(yss[0].shape[0])]
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/lime/lime_text.py:482, in LimeTextExplainer.__data_labels_distances(self, indexed_string, classifier_fn, num_samples, distance_metric)
#     480     data[i, inactive] = 0
#     481     inverse_data.append(indexed_string.inverse_removing(inactive))
# --> 482 labels = classifier_fn(inverse_data)
#     483 distances = distance_fn(sp.sparse.csr_matrix(data))
#     484 return data, labels, distances
#
# File ~/Programming/harvardCS/PruningExplainability/explainers/explanation_methods.py:56, in LIME.predict_proba(self, texts)
#      45 """
#      46 Prediction function for LIME explainer
#      47
#    (...)
#      52     predictions (numpy.ndarray): Array of prediction probabilities
#      53 """
#      54 inputs = self.tokenizer(
#      55     texts, return_tensors="pt", padding=True, truncation=True)
# ---> 56 outputs = self.model(**inputs)
#      57 probabilities = softmax(outputs.logits, dim=-1).detach().numpy()
#      59 return probabilities
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/transformers/models/distilbert/modeling_distilbert.py:883, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     875 r"""
#     876 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     877     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     878     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     879     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     880 """
#     881 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 883 distilbert_output = self.distilbert(
#     884     input_ids=input_ids,
#     885     attention_mask=attention_mask,
#     886     head_mask=head_mask,
#     887     inputs_embeds=inputs_embeds,
#     888     output_attentions=output_attentions,
#     889     output_hidden_states=output_hidden_states,
#     890     return_dict=return_dict,
#     891 )
#     892 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     893 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/transformers/models/distilbert/modeling_distilbert.py:703, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     700     if attention_mask is None:
#     701         attention_mask = torch.ones(input_shape, device=device)  # (bs, seq_length)
# --> 703 return self.transformer(
#     704     x=embeddings,
#     705     attn_mask=attention_mask,
#     706     head_mask=head_mask,
#     707     output_attentions=output_attentions,
#     708     output_hidden_states=output_hidden_states,
#     709     return_dict=return_dict,
#     710 )
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/transformers/models/distilbert/modeling_distilbert.py:464, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     456     layer_outputs = self._gradient_checkpointing_func(
#     457         layer_module.__call__,
#     458         hidden_state,
#    (...)
#     461         output_attentions,
#     462     )
#     463 else:
# --> 464     layer_outputs = layer_module(
#     465         hidden_state,
#     466         attn_mask,
#     467         head_mask[i],
#     468         output_attentions,
#     469     )
#     471 hidden_state = layer_outputs[-1]
#     473 if output_attentions:
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/transformers/models/distilbert/modeling_distilbert.py:390, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     380 """
#     381 Parameters:
#     382     x: torch.tensor(bs, seq_length, dim)
#    (...)
#     387     torch.tensor(bs, seq_length, dim) The output of the transformer block contextualization.
#     388 """
#     389 # Self-Attention
# --> 390 sa_output = self.attention(
#     391     query=x,
#     392     key=x,
#     393     value=x,
#     394     mask=attn_mask,
#     395     head_mask=head_mask,
#     396     output_attentions=output_attentions,
#     397 )
#     398 if output_attentions:
#     399     sa_output, sa_weights = sa_output  # (bs, seq_length, dim), (bs, n_heads, seq_length, seq_length)
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Programming/harvardCS/PruningExplainability/env/lib/python3.12/site-packages/transformers/models/distilbert/modeling_distilbert.py:225, in MultiHeadSelfAttention.forward(self, query, key, value, mask, head_mask, output_attentions)
#     222 if head_mask is not None:
#     223     weights = weights * head_mask
# --> 225 context = torch.matmul(weights, v)  # (bs, n_heads, q_length, dim_per_head)
#     226 context = unshape(context)  # (bs, q_length, dim)
#     227 context = self.out_lin(context)  # (bs, q_length, dim)
#
# KeyboardInterrupt:

# %%
# [PAD] token maps to `0`
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification


model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
tokenizer('[PAD]')
tokenizer('[MASK]')
# Out:
# {'input_ids': [101, 103, 102], 'attention_mask': [1, 1, 1]}
