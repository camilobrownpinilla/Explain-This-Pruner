# %% [markdown]
# Notebook to test displays.
#
# Supports any model & tokenizer from huggingface

# %%
from transformers import AutoTokenizer, BertForSequenceClassification
from explainers.explanation_methods import SHAP, LIME
import shap
import torch


tokenizer = AutoTokenizer.from_pretrained(
    "textattack/bert-base-uncased-yelp-polarity")
model = BertForSequenceClassification.from_pretrained(
    "textattack/bert-base-uncased-yelp-polarity")
print('model loaded')

input = 'Hello, my dog is so terribly ugly'
tokenized_input = tokenizer(input, return_tensors="pt")
label = torch.tensor([0]).unsqueeze(0)  # Batch size 1

with torch.no_grad():
    output = model(**tokenized_input, labels=label)
    
loss, logits = output[:2]
predicted_class_id = logits.argmax().item()
predicted_class = model.config.id2label[predicted_class_id] 
true_class = model.config.id2label[label[0].item()]   

print(f'input: {input}\n logits: {logits} \n predicted class: {predicted_class} \n true class: {true_class}')


explainer = SHAP(model, tokenizer)
explanation = explainer.explain(input)
print('SHAP explanation: ', explanation)

shap.plots.text(explanation)
# Out:
# model loaded
# input: Hello, my dog is so terribly ugly
#  logits: tensor([[ 4.5232, -4.2648]])
#  predicted class: LABEL_0
#  true class: LABEL_0
# SHAP explanation:  .values =
# array([[[ 0.        ,  0.        ],
#         [-0.10023548,  0.10023542],
#         [ 0.011923  , -0.01192299],
#         [-0.01269054,  0.01269055],
#         [ 0.0038579 , -0.0038579 ],
#         [ 0.02124363, -0.02124363],
#         [ 0.04590302, -0.04590301],
#         [ 0.02927343, -0.02927346],
#         [ 0.02953256, -0.02953256],
#         [ 0.        ,  0.        ]]])
#
# .base_values =
# array([[0.97103989, 0.02896013]])
#
# .data =
# (array(['', 'Hello', ', ', 'my ', 'dog ', 'is ', 'so ', 'terribly ',
#        'ugly', ''], dtype=object),)
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_buanteefsfmmleqdekif = '_tp_buanteefsfmmleqdekif_output_0';
#     document._zoom_buanteefsfmmleqdekif = undefined;
#     function _output_onclick_buanteefsfmmleqdekif(i) {
#         var next_id = undefined;
#
#         if (document._zoom_buanteefsfmmleqdekif !== undefined) {
#             document.getElementById(document._zoom_buanteefsfmmleqdekif+ '_zoom').style.display = 'none';
#
#             if (document._zoom_buanteefsfmmleqdekif === '_tp_buanteefsfmmleqdekif_output_' + i) {
#                 document.getElementById(document._zoom_buanteefsfmmleqdekif).style.display = 'block';
#                 document.getElementById(document._zoom_buanteefsfmmleqdekif+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_buanteefsfmmleqdekif).style.display = 'none';
#                 document.getElementById(document._zoom_buanteefsfmmleqdekif+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_buanteefsfmmleqdekif !== '_tp_buanteefsfmmleqdekif_output_' + i) {
#             next_id = '_tp_buanteefsfmmleqdekif_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_buanteefsfmmleqdekif = next_id;
#     }
#     function _output_onmouseover_buanteefsfmmleqdekif(i, el) {
#         if (document._zoom_buanteefsfmmleqdekif !== undefined) { return; }
#         if (document._hover_buanteefsfmmleqdekif !== undefined) {
#             document.getElementById(document._hover_buanteefsfmmleqdekif + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_buanteefsfmmleqdekif).style.display = 'none';
#         }
#         document.getElementById('_tp_buanteefsfmmleqdekif_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_buanteefsfmmleqdekif = '_tp_buanteefsfmmleqdekif_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(1.0)); border-radius: 3px; padding: 0px" id="_tp_buanteefsfmmleqdekif_output_0_name"
#     onclick="_output_onclick_buanteefsfmmleqdekif(0)"
#     onmouseover="_output_onmouseover_buanteefsfmmleqdekif(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(230.2941176470614), np.float64(26.505882352939775), np.float64(102.59215686274348), np.float64(0.0)); border-radius: 3px; padding: 0px" id="_tp_buanteefsfmmleqdekif_output_1_name"
#     onclick="_output_onclick_buanteefsfmmleqdekif(1)"
#     onmouseover="_output_onmouseover_buanteefsfmmleqdekif(1, this);">LABEL_1</div><br><br><div id='_tp_buanteefsfmmleqdekif_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.9999995607735%" y1="33" x2="49.9999995607735%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.9999995607735%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.33189722599452%" y1="33" x2="34.33189722599452%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.33189722599452%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.663794891215517%" y1="33" x2="18.663794891215517%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.663794891215517%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="65.6681018955525%" y1="33" x2="65.6681018955525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.6681018955525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="81.33620423033152%" y1="33" x2="81.33620423033152%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.33620423033152%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="86.90150565956448%" y1="33" x2="86.90150565956448%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="86.90150565956448%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.97104</text><text x="86.90150565956448%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.97104</text><text x="86.90150565956448%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="89.1583015842942%" y1="33" x2="89.1583015842942%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.1583015842942%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999847</text><text x="89.1583015842942%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.999847</text><text x="89.1583015842942%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="78.05482395970805%" width="11.103477624586153%" y="40" height="18" style="fill:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179)); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="85.56223524905857%" x2="89.1583015842942%" y1="60" y2="60" id="_fb_exncufsdirsbzpsdlfus_ind_6" style="stroke:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179));stroke-width:2; opacity: 0"/><text x="87.36026841667638%" y="71" font-size="12px" id="_fs_exncufsdirsbzpsdlfus_ind_6" fill="rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179))" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.046</text><svg x="85.56223524905857%" y="40" height="20" width="3.5960663352356192%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">so</text>  </svg></svg><line x1="83.24863944903578%" x2="85.56223524905857%" y1="60" y2="60" id="_fb_exncufsdirsbzpsdlfus_ind_8" style="stroke:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.0808360603179));stroke-width:2; opacity: 0"/><text x="84.40543734904718%" y="71" font-size="12px" id="_fs_exncufsdirsb ...

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification


model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
model = DistilBertForSequenceClassification.from_pretrained(model_name)
print('model loaded')

input = "i went and saw this movie last night after being coaxed to by a few friends of mine . i ' ll admit that i was reluctant to see it because from what i knew of ashton kutcher he was only able to do comedy . i was wrong . kutcher played the character of jake fischer very well , and kevin costner played ben randall with such professionalism . the sign of a good movie is that it can toy with our emotions . this one did exactly that . the entire theater ( which was sold out ) was overcome by laughter during the"

explainer = LIME(model, tokenizer)
explanation = explainer.explain(input)
print('explanation obtained')
shap.plots.text(explanation)
